# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import statsmodels.graphics.gofplots as sm
import seaborn as sns
from scipy.stats import beta

# %%
# import dataset from nCoV2019-master/latest_data on April 13, 2020
# renamed latestdata.csv as covid_data_apr_13.csv
ds = pd.read_csv("covid_data_apr_13.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (1,2,9,10,12,13,14,15,16,17,18,19,21,22,23,24,25,26,27,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def get_first_digit(x):
    while x >= 10:
        x /= 10
    return int(x)
def get_sec_digit(x):
    while x >= 100:
        x /= 10
    return int(x%10)
def get_first_two_digits(x):
    while x >= 100:
        x /= 10
    return int(x)

# %%
# chinese data
china = ds[ds.country.eq("China")]

# chinese city counts
china_city_counts = np.array(china['city'].value_counts())
china_city_greater10 = china_city_counts[china_city_counts >= 10]

# chinese province counts
china_prov_counts = np.array(china['province'].value_counts())
china_prov_greater10 = china_prov_counts[china_prov_counts >= 10]

# %%
# extracting first, second, and first two digits from chinese city counts
china_city_first = [get_first_digit(x) for x in china_city_counts]
china_city_second = [get_sec_digit(x) for x in china_city_greater10]
china_city_firsttwo = [get_first_two_digits(x) for x in china_city_greater10]

# extracting first, second, and first two digits from chinese province counts
china_prov_first = [get_first_digit(x) for x in china_prov_counts]
china_prov_second = [get_sec_digit(x) for x in china_prov_greater10]
china_prov_firsttwo = [get_first_two_digits(x) for x in china_prov_greater10]

# %%
# chinese cities: histograms
# first digit
plt.hist(china_city_first, bins=9,density=True)
plt.title("Frequency of First Digits among COVID19 counts in Chinese Cities/Counties"+"\n (Sample Size: " 
          + str(len(china_city_first))+")")
plt.xlabel("First Digit")
plt.ylabel("Relative Frequency")
plt.show()

# second digit
plt.hist(china_city_second, bins=10,density=True)
plt.title("Frequency of second digits among COVID19 counts in Chinese Cities/Counties"+"\n (Sample Size: " 
          + str(len(china_city_second))+")")
plt.xlabel("Second Digit")
plt.ylabel("Relative Frequency")
plt.show()

# first two digits
plt.hist(china_city_firsttwo, bins=90,density=True)
plt.title("Frequency of First Two digits among COVID19 counts in Chinese Cities/Counties"+"\n (Sample Size: " 
          + str(len(china_city_firsttwo))+")")
plt.xlabel("First Two Digits")
plt.ylabel("Relative Frequency")
plt.show()

# %%
# chinese provinces: histograms

# first digit
plt.hist(china_prov_first, bins=9,density=True)
plt.title("Frequency of First Digits among COVID19 counts in Chinese Provinces"+"\n (Sample Size: " 
          + str(len(china_prov_first))+")")
plt.xlabel("First Digit")
plt.ylabel("Relative Frequency")
plt.show()

# second digit
plt.hist(china_prov_second, bins=10,density=True)
plt.title("Frequency of second digits among COVID19 counts in Chinese Provinces"+"\n (Sample Size: " 
          + str(len(china_prov_second))+")")
plt.xlabel("Second Digit")
plt.ylabel("Relative Frequency")
plt.show()

# first two digits
plt.hist(china_prov_firsttwo, bins=90,density=True)
plt.title("Frequency of First Two digits among COVID19 counts in Chinese Provinces"+"\n (Sample Size: " 
          + str(len(china_prov_firsttwo))+")")
plt.xlabel("First Two Digits")
plt.ylabel("Relative Frequency")
plt.show()

# %%
# us data
us = ds[ds.country.eq("United States")]

# us city counts
us_city_counts = np.array(us['city'].value_counts())
us_city_greater10 = us_city_counts[us_city_counts >= 10]

# us province counts
us_prov_counts = np.array(us['province'].value_counts())
us_prov_greater10 = us_prov_counts[us_prov_counts >= 10]

# %%
# extracting first, second, and first two digits from us city counts
us_city_first = [get_first_digit(x) for x in us_city_counts]
us_city_second = [get_sec_digit(x) for x in us_city_greater10]
us_city_firsttwo = [get_first_two_digits(x) for x in us_city_greater10]

# extracting first, second, and first two digits from us province counts
us_prov_first = [get_first_digit(x) for x in us_prov_counts]
us_prov_second = [get_sec_digit(x) for x in us_prov_greater10]
us_prov_firsttwo = [get_first_two_digits(x) for x in us_prov_greater10]

# %%
# us cities: histograms

# first digit
plt.hist(us_city_first, bins=9,density=True)
plt.title("Frequency of First Digits among COVID19 counts in US Cities/Counties"+"\n (Sample Size: " 
          + str(len(us_city_first))+")")
plt.xlabel("First Digit")
plt.ylabel("Relative Frequency")
plt.show()

# second digit
plt.hist(us_city_second, bins=10,density=True)
plt.title("Frequency of second digits among COVID19 counts in US Cities/Counties"+"\n (Sample Size: " 
          + str(len(us_city_second))+")")
plt.xlabel("Second Digit")
plt.ylabel("Relative Frequency")
plt.show()

# first two digits
plt.hist(us_city_firsttwo, bins=90,density=True)
plt.title("Frequency of First Two digits among COVID19 counts in US Cities/Counties"+"\n (Sample Size: " 
          + str(len(us_city_firsttwo))+")")
plt.xlabel("First Two Digits")
plt.ylabel("Relative Frequency")
plt.show()

# %%
# us provinces: histograms

# first digit
plt.hist(us_prov_first, bins=9,density=True)
plt.title("Frequency of First Digits among COVID19 counts in US Provinces"+"\n (Sample Size: " 
          + str(len(us_prov_first))+")")
plt.xlabel("First Digit")
plt.ylabel("Relative Frequency")
plt.show()

# second digit
plt.hist(us_prov_second, bins=10,density=True)
plt.title("Frequency of second digits among COVID19 counts in US Provinces"+"\n (Sample Size: " 
          + str(len(us_prov_second))+")")
plt.xlabel("Second Digit")
plt.ylabel("Relative Frequency")
plt.show()

# first two digits
plt.hist(us_prov_firsttwo, bins=90,density=True)
plt.title("Frequency of First Two digits among COVID19 counts in US Provinces"+"\n (Sample Size: " 
          + str(len(us_prov_firsttwo))+")")
plt.xlabel("First Two Digits")
plt.ylabel("Relative Frequency")
plt.show()

# %%
no_china = ds[ds.country.ne("China")]
no_china
# Out:
#                 ID    age     sex            city    province        country  \
# 0          000-1-1  60-69  female  Whatcom County  Washington  United States
# 3         000-1-10  60-69  female   Pitkin County    Colorado  United States
# 4        000-1-100     44    male             NaN      Zurich    Switzerland
# 7       000-1-1000    NaN     NaN             NaN     Hamburg        Germany
# 19      000-1-1001    NaN     NaN             NaN     Hamburg        Germany
# 31      000-1-1002    NaN     NaN             NaN     Hamburg        Germany
# 43      000-1-1003    NaN     NaN             NaN     Hamburg        Germany
# 55      000-1-1004    NaN     NaN             NaN     Hamburg        Germany
# 67      000-1-1005    NaN     NaN             NaN     Hamburg        Germany
# 79      000-1-1006    NaN     NaN             NaN     Hamburg        Germany
# 90      000-1-1007    NaN     NaN             NaN     Hamburg        Germany
# 102     000-1-1008    NaN     NaN             NaN     Hamburg        Germany
# 115     000-1-1009    NaN     NaN             NaN     Hamburg        Germany
# 126      000-1-101     45    male             NaN      Zurich    Switzerland
# 128     000-1-1010    NaN     NaN             NaN     Hamburg        Germany
# 141     000-1-1011    NaN     NaN             NaN     Hamburg        Germany
# 152     000-1-1012    NaN     NaN             NaN     Hamburg        Germany
# 164     000-1-1013    NaN     NaN             NaN     Hamburg        Germany
# 176     000-1-1014    NaN     NaN             NaN     Hamburg        Germany
# 188     000-1-1015    NaN     NaN             NaN     Hamburg        Germany
# 200     000-1-1016    NaN     NaN             NaN     Hamburg        Germany
# 213     000-1-1017    NaN     NaN             NaN     Hamburg        Germany
# 225     000-1-1018    NaN     NaN             NaN     Hamburg        Germany
# 237     000-1-1019    NaN     NaN             NaN     Hamburg        Germany
# 249     000-1-1020    NaN     NaN             NaN     Hamburg        Germany
# 260     000-1-1021    NaN     NaN             NaN     Hamburg        Germany
# 273     000-1-1022    NaN     NaN             NaN     Hamburg        Germany
# 285     000-1-1023    NaN     NaN             NaN     Hamburg        Germany
# 296     000-1-1024    NaN     NaN             NaN     Hamburg        Germany
# 308     000-1-1025    NaN     NaN             NaN     Hamburg        Germany
# ...            ...    ...     ...             ...         ...            ...
# 267462    006-9972    NaN     NaN   New York City    New York  United States
# 267463    006-9973    NaN     NaN   New York City    New York  United States
# 267464    006-9974    NaN     NaN   New York City    New York  United States
# 267465    006-9975    NaN     NaN   New York City    New York  United States
# 267466    006-9976    NaN     NaN   New York City    New York  United States
# 267467    006-9977    NaN     NaN   New York City    New York  United States
# 267468    006-9978    NaN     NaN   New York City    New York  United States
# 267469    006-9979    NaN     NaN   New York City    New York  United States
# 267470     006-998    NaN     NaN   New York City    New York  United States
# 267471    006-9980    NaN     NaN   New York City    New York  United States
# 267472    006-9981    NaN     NaN   New York City    New York  United States
# 267473    006-9982    NaN     NaN   New York City    New York  United States
# 267474    006-9983    NaN     NaN   New York City    New York  United States
# 267475    006-9984    NaN     NaN   New York City    New York  United States
# 267476    006-9985    NaN     NaN   New York City    New York  United States
# 267477    006-9986    NaN     NaN   New York City    New York  United States
# 267478    006-9987    NaN     NaN   New York City    New York  United States
# 267479    006-9988    NaN     NaN   New York City    New York  United States
# 267480    006-9989    NaN     NaN   New York City    New York  United States
# 267481     006-999    NaN     NaN   New York City    New York  United States
# 267482    006-9990    NaN     NaN   New York City    New York  United States
# 267483    006-9991    NaN     NaN   New York City    New York  United States
# 267484    006-9992    NaN     NaN   New York City    New York  United States
# 267485    006-9993    NaN     NaN   New York City    New York  United States
# 267486    006-9994    NaN     NaN   New York City    New York  United States
# 267487    006-9995    NaN     NaN   New York City    New York  United States
# 267488    006-9996    NaN     NaN   New York City    New York  United States
# 267489    006-9997    NaN     NaN   New York City    New York  United States
# 267490    006-9998    NaN     NaN   New York City    New York  United States
# 267491    006-9999    NaN     NaN   New York City    New York  United States
#
#          latitude   longitude geo_resolution date_onset_symptoms  \
# 0       48.826129 -121.719290         admin2                 NaN
# 3       39.217302 -106.915280         admin2                 NaN
# 4       47.417813    8.655968         admin1                 NaN
# 7       53.546610   10.020720         admin1                 NaN
# 19      53.546610   10.020720         admin1                 NaN
# 31      53.546610   10.020720         admin1                 NaN
# 43      53.546610   10.020720         admin1                 NaN
# 55      53.546610   10.020720         admin1                 NaN
# 67      53.546610   10.020720         admin1                 NaN
# 79      53.546610   10.020720         admin1                 NaN
# 90      53.546610   10.020720         admin1                 NaN
# 102     53.546610   10.020720         admin1                 NaN
# 115     53.546610   10.020720         admin1                 NaN
# 126     47.417813    8.655968         admin1                 NaN
# 128     53.546610   10.020720         admin1                 NaN
# 141     53.546610   10.020720         admin1                 NaN
# 152     53.546610   10.020720         admin1                 NaN
# 164     53.546610   10.020720         admin1                 NaN
# 176     53.546610   10.020720         admin1                 NaN
# 188     53.546610   10.020720         admin1                 NaN
# 200     53.546610   10.020720         admin1                 NaN
# 213     53.546610   10.020720         admin1                 NaN
# 225     53.546610   10.020720         admin1                 NaN
# 237     53.546610   10.020720         admin1                 NaN
# 249     53.546610   10.020720         admin1                 NaN
# 260     53.546610   10.020720         admin1                 NaN
# 273     53.546610   10.020720         admin1                 NaN
# 285     53.546610   10.020720         admin1                 NaN
# 296     53.546610   10.020720         admin1                 NaN
# 308     53.546610   10.020720         admin1                 NaN
# ...           ...         ...            ...                 ...
# 267462  40.661000  -73.944000          point                 NaN
# 267463  40.661000  -73.944000          point                 NaN
# 267464  40.661000  -73.944000          point                 NaN
# 267465  40.661000  -73.944000          point                 NaN
# 267466  40.661000  -73.944000          point                 NaN
# 267467  40.661000  -73.944000          point                 NaN
# 267468  40.661000  -73.944000          point                 NaN
# 267469  40.661000  -73.944000          point                 NaN
# 267470  40.661000  -73.944000          point                 NaN
# 267471  40.661000  -73.944000          point                 NaN
# 267472  40.661000  -73.944000          point                 NaN
# 267473  40.661000  -73.944000          point                 NaN
# 267474  40.661000  -73.944000          point                 NaN
# 267475  40.661000  -73.944000          point                 NaN
# 267476  40.661000  -73.944000          point                 NaN
# 267477  40.661000  -73.944000          point                 NaN
# 267478  40.661000  -73.944000          point                 NaN
# 267479  40.661000  -73.944000          point                 NaN
# 267480  40.661000  -73.944000          point                 NaN
# 267481  40.661000  -73.944000          point                 NaN
# 267482  40.661000  -73.944000          point                 NaN
# 267483  40.661000  -73.944000          point                 NaN
# 267484  40.661000  -73.944000          point                 NaN
# 267485  40.661000  -73.944000          point                 NaN
# 267486  40.661000  -73.944000          point                 NaN
# 267487  40.661000  -73.944000          point                 NaN
# 267488  40.661000  -73.944000          point                 NaN
# 267489  40.661000  -73.944000          point                 NaN
# 267490  40.661000  -73.944000          point                 NaN
# 267491  40.661000  -73.944000          point                 NaN
#
#                 ...          date_death_or_discharge notes_for_discussion  \
# 0               ...                              NaN                  NaN
# 3               ...                              NaN                  NaN
# 4               ...                              NaN                  NaN
# 7               ...                              NaN                  NaN
# 19              ...                              NaN                  NaN
# 31              ...                              NaN                  NaN
# 43              ...                              NaN                  NaN
# 55              ...                              NaN                  NaN
# 67              ...                              NaN                  NaN
# 79              ...                              NaN                  NaN
# 90              ...                              NaN                  NaN
# 102             ...                              NaN                  NaN
# 115             ...                              NaN                  NaN
# 126             ...                              NaN                  NaN
# 128             ...                              NaN                  NaN
# 141             ...                              NaN                  NaN
# 152             ...                              NaN                  NaN
# 164             ...                              NaN                  NaN
# 176             ...                              NaN                  NaN
# 188             ...                              NaN                  NaN
# 200             ...                              NaN                  NaN
# 213             ...                              NaN                  NaN
# 225             ...                              NaN                  NaN
# 237             ...                              NaN                  NaN
# 249             ...                              NaN                  NaN
# 260             ...                              NaN                  NaN
# 273             ...                              NaN                  NaN
# 285             ...                              NaN                  NaN
# 296             ...                              NaN                  NaN
# 308             ...                              NaN                  NaN
# ...             ...                              ...                  ...
# 267462          ...                              NaN                  NaN
# 267463          ...                              NaN                  NaN
# 267464          ...                              NaN                  NaN
# 267465          ...                              NaN                  NaN
# 267466          ...                              NaN                  NaN
# 267467          ...                              NaN                  NaN
# 267468          ...                              NaN                  NaN
# 267469          ...                              NaN                  NaN
# 267470          ...                              NaN                  NaN
# 267471          ...                              NaN                  NaN
# 267472          ...                              NaN                  NaN
# 267473          ...                              NaN                  NaN
# 267474          ...                              NaN                  NaN
# 267475          ...                              NaN                  NaN
# 267476          ...                              NaN                  NaN
# 267477          ...                              NaN                  NaN
# 267478          ...                              NaN                  NaN
# 267479          ...                              NaN                  NaN
# 267480          ...                              NaN                  NaN
# 267481          ...                              NaN                  NaN
# 267482          ...                              NaN                  NaN
# 267483          ...                              NaN                  NaN
# 267484          ...                              NaN                  NaN
# 267485          ...                              NaN                  NaN
# 267486          ...                              NaN                  NaN
# 267487          ...                              NaN                  NaN
# 267488          ...                              NaN                  NaN
# 267489          ...                              NaN                  NaN
# 267490          ...                              NaN                  NaN
# 267491          ...                              NaN                  NaN
#
#        location admin3          admin2      admin1    country_new admin_id  \
# 0           NaN    NaN  Whatcom County  Washington  United States   2994.0
# 3           NaN    NaN   Pitkin County    Colorado  United States    291.0
# 4           NaN    NaN             NaN      Zurich    Switzerland     26.0
# 7           NaN    NaN             NaN     Hamburg        Germany      6.0
# 19          NaN    NaN             NaN     Hamburg        Germany      6.0
# 31          NaN    NaN             NaN     Hamburg        Germany      6.0
# 43          NaN    NaN             NaN     Hamburg        Germany      6.0
# 55          NaN    NaN             NaN     Hamburg        Germany      6.0
# 67          NaN    NaN             NaN     Hamburg        Germany      6.0
# 79          NaN    NaN             NaN     Hamburg        Germany      6.0
# 90          NaN    NaN             NaN     Hamburg        Germany      6.0
# 102         NaN    NaN             NaN     Hamburg        Germany      6.0
# 115         NaN    NaN             NaN     Hamburg        Germany      6.0
# 126         NaN    NaN             NaN      Zurich    Switzerland     26.0
# 128         NaN    NaN             NaN     Hamburg        Germany      6.0
# 141         NaN    NaN             NaN     Hamburg        Germany      6.0
# 152         NaN    NaN             NaN     Hamburg        Germany      6.0
# 164         NaN    NaN             NaN     Hamburg        Germany      6.0
# 176         NaN    NaN             NaN     Hamburg        Germany      6.0
# 188         NaN    NaN             NaN     Hamburg        Germany      6.0
# 200         NaN    NaN             NaN     Hamburg        Germany      6.0
# 213         NaN    NaN             NaN     Hamburg        Germany      6.0
# 225         NaN    NaN             NaN     Hamburg        Germany      6.0
# 237         NaN    NaN             NaN     Hamburg        Germany      6.0
# 249         NaN    NaN             NaN     Hamburg        Germany      6.0
# 260         NaN    NaN             NaN     Hamburg        Germany      6.0
# 273         NaN    NaN             NaN     Hamburg        Germany      6.0
# 285         NaN    NaN             NaN     Hamburg        Germany      6.0
# 296         NaN    NaN             NaN     Hamburg        Germany      6.0
# 308         NaN    NaN             NaN     Hamburg        Germany      6.0
# ...         ...    ...             ...         ...            ...      ...
# 267462      NaN    NaN             NaN    New York  United States     33.0
# 267463      NaN    NaN             NaN    New York  United States     33.0
# 267464      NaN    NaN             NaN    New York  United States     33.0
# 267465      NaN    NaN             NaN    New York  United States     33.0
# 267466      NaN    NaN             NaN    New York  United States     33.0
# 267467      NaN    NaN             NaN    New York  United States     33.0
# 267468      NaN    NaN             NaN    New York  United States     33.0
# 267469      NaN    NaN             NaN    New York  United States     33.0
# 267470      NaN    NaN             NaN    New York  United States     33.0
# 267471      NaN    NaN             NaN    New York  United States     33.0
# 267472      NaN    NaN             NaN    New York  United States     33.0
# 267473      NaN    NaN             NaN    New York  United States     33.0
# 267474      NaN    NaN             NaN    New York  United States     33.0
# 267475      NaN    NaN             NaN    New York  United States     33.0
# 267476      NaN    NaN             NaN    New York  United States     33.0
# 267477      NaN    NaN             NaN    New York  United States     33.0
# 267478      NaN    NaN             NaN    New York  United States     33.0
# 267479      NaN    NaN             NaN    New York  United States     33.0
# 267480      NaN    NaN             NaN    New York  United States     33.0
# 267481      NaN    NaN             NaN    New York  United States     33.0
# 267482      NaN    NaN             NaN    New York  United States     33.0
# 267483      NaN    NaN             NaN    New York  United States     33.0
# 267484      NaN    NaN             NaN    New York  United States     33.0
# 267485      NaN    NaN             NaN    New York  United States     33.0
# 267486      NaN    NaN             NaN    New York  United States     33.0
# 267487      NaN    NaN             NaN    New York  United States     33.0
# 267488      NaN    NaN             NaN    New York  United States     33.0
# 267489      NaN    NaN             NaN    New York  United States     33.0
# 267490      NaN    NaN             NaN    New York  United States     33.0
# 267491      NaN    NaN             NaN    New York  United States     33.0
#
#        data_moderator_initials travel_history_binary
# 0                          NaN                   NaN
# 3                          NaN                   NaN
# 4                          NaN                   NaN
# 7                          NaN                   NaN
# 19                         NaN                   NaN
# 31                         NaN                   NaN
# 43                         NaN                   NaN
# 55                         NaN                   NaN
# 67                         NaN                   NaN
# 79                         NaN                   NaN
# 90                         NaN                   NaN
# 102                        NaN                   NaN
# 115                        NaN                   NaN
# 126                        NaN                   NaN
# 128                        NaN                   NaN
# 141                        NaN                   NaN
# 152                        NaN                   NaN
# 164                        NaN                   NaN
# 176                        NaN                   NaN
# 188                        NaN                   NaN
# 200                        NaN                   NaN
# 213                        NaN                   NaN
# 225                        NaN                   NaN
# 237                        NaN                   NaN
# 249                        NaN                   NaN
# 260                        NaN                   NaN
# 273                        NaN                   NaN
# 285                        NaN                   NaN
# 296                        NaN                   NaN
# 308                        NaN                   NaN
# ...                        ...                   ...
# 267462                     NaN                   NaN
# 267463                     NaN                   NaN
# 267464                     NaN                   NaN
# 267465                     NaN                   NaN
# 267466                     NaN                   NaN
# 267467                     NaN                   NaN
# 267468                     NaN                   NaN
# 267469                     NaN                   NaN
# 267470                     NaN                   NaN
# 267471                     NaN                   NaN
# 267472                     NaN                   NaN
# 267473                     NaN                   NaN
# 267474                     NaN                   NaN
# 267475                     NaN                   NaN
# 267476                     NaN                   NaN
# 267477                     NaN                   NaN
# 267478                     NaN                   NaN
# 267479                     NaN                   NaN
# 267480                     NaN                   NaN
# 267481                     NaN                   NaN
# 267482                     NaN                   NaN
# 267483                     NaN                   NaN
# 267484                     NaN                   NaN
# 267485                     NaN                   NaN
# 267486                     NaN                   NaN
# 267487                     NaN                   NaN
# 267488                     NaN                   NaN
# 267489                     NaN                   NaN
# 267490                     NaN                   NaN
# 267491                     NaN                   NaN
#
# [225193 rows x 33 columns]

# %%
prov_counts_no_ch = no_china['province'].value_counts()
prov_first_dig_no_ch = [get_first_digit(x) for x in prov_counts_no_ch]
plt.hist(prov_first_dig_no_ch,bins=9,density=True)
plt.show()

# %%
korea = ds[ds.country.eq("South Korea")]
korea

# %%
korea.province.unique()

# %%
prov_counts_kr = korea['province'].value_counts()
prov_first_dig_kr = [get_first_digit(x) for x in prov_counts_kr]
plt.hist(prov_first_dig_kr,bins=9)
plt.show()

# %%
city_counts_kr = korea['city'].value_counts()
print(city_counts_kr)
city_first_dig_kr = [get_first_digit(x) for x in city_counts_kr]
plt.hist(city_first_dig_kr,bins=9)
plt.show()
